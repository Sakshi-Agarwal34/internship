# %%
def maximun(n1,n2,n3):
    if(n1<n2):
        if(n2<n3):
            print("maximum is",n3)
        else:
            print("maximun is", n2)
    else:
        if(n1<n3):
            print("maximun is",n3)
        else:
            print("maximum is",n1)
a=int(input("enter number"))
b=int(input("enter number")) 
c=int(input("enter number"))
maximun(a,b,c)
# Out:
# maximun is 10

# %%
def maximun(n1,n2,n3):
 max=n1
 if(max<n2):
  max=n2 
 if(max<n3):
  max=n3
 print("maximum is",max)
a=int(input("enter number"))
b=int(input("enter number")) 
c=int(input("enter number"))
maximun(a,b,c)
# Out:
# maximum is 8

# %%
def list(i):
    r=[]
    for x in i:
        
        if x not in r:
            r.append(x)
    print(r)        
l=[10,20,30,40,40]
list(l)
# Out:
# [10, 20, 30, 40]

# %%
def multiply(list2):
    mul=1
    for x in list2:
        mul*=x
    print("multiply of all list mumber",mul) 
list=[1,5,8,5,7,8,9,2,4]
multiply(list)
# Out:
# multiply of all list mumber 806400

# %%
f=1
def fact(n):
    global f
    
    if(n>0):  
       f=f*n
       fact(n-1)
       
    else:
        print(f)
  
n=int(input("enter a number"))
fact(n)
# Out:
# 3628800

# %%
def reverse (n):
    m=""
    for x in n:
        m=x+m
    print("reverse of given string",m)
n=input("eneter a string")
reverse(n)
# Out:
# reverse of given string ehdar

# %%
def fallinrange(num,start,end):
    if(num>=start and num<=end):
        print("number in given range")
    else:
        print("out of range")
a=int(input("numer")) 
b=int(input("numer"))            
c=int(input("numer"))
fallinrange(a,b,c)
# Out:
# number in given range

# %%
def list(list1):
    res=[]
    for x in list1:
        if(x%2==0):
            res.append(x)
    print("even number of string",res)
l=[10,5,3,8,2,8,7]
list(l)
# Out:
# even number of string [10, 8, 2, 8]

# %%
def str(string):
    i=0;
    j=0;
    for x in string:
        if(65<=ord(x)and 90>=ord(x)):
            i+=1
        else:
            j+=1
    print("numbrr of upper case letter in  string",i)
    print("number of lower case letter",j)
s=input("enter a string")
str(s)

# %%
def prime(num):
    n = a
    
    if num == 1:
        print("number is prime")
    
    elif n % num == 0:
        print("number is not prime")
    
    else:
        prime(num - 1)

a = int(input("enter number: "))

if a <= 1:
    print("number is not prime")
else:
    prime(a - 1)
# Out:
# number is prime
