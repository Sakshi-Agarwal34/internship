# %%
import numpy as np
a=np.array([[6,-8,73,-110],[np.nan,-8,0,94]])
print(a)
a[1,0]=0
print(a)
b=np.array([[6,-8,73,-110],[np.nan,-8,0,94]])
print(b)
b=np.nan_to_num(b,nan=0)
print(b)
t=b.T
print(t)
print(b.reshape(2,4))

# %%
import numpy as np
c=np.array([[[1,2,3,5],[5,6,7,8]],[[1,5,6,0],[4,5,6,8]]])
print(c)
print(c.shape)
d=np.moveaxis(c,2,0)
print(d)
print(d.shape)

# %%
import numpy as np

arr = np.array([[1, np.nan, 3],
                [4, 5, np.nan],
                [7, 8, 9]])

# Column-wise mean (NaN को ignore करके)
col_mean = np.nanmean(arr, axis=0)

# NaN की positions
inds = np.where(np.isnan(arr))

# NaN को column mean से replace करना
arr[inds] = np.take(col_mean, inds[1])

print(arr)

# %%
import numpy as np
a=np.array([[6,-8,73,-110],[np.nan,-8,0,94]])
print(a)
c=np.nan_to_num(a,nan=0)
b=np.where(c<0,0,a)

# %%
arr1=np.array([3,4])
arr2=np.array([1,0])
avg=(arr1+arr2)/2
print("avrage of both array",avg)

# %%
import numpy as np
a=np.array([[[1,2,3],[4,5,6]],[[3,4,5],[7,8,9]]])
print(np.mean(a))
print(np.median(a))
values,counts=np.unique(a,return_counts=True)
mode=values[np.argmax(counts)]
print(mode)

# %%
import numpy as np

a=np.array([[[1,-2,3],[-1,3,-1],[2,-5,5]]])
b=np.array([9,-6,177])
res=np.linalg.solve(a,b)
print(res)
# Out:
# [[-1119.  -321.   162.]]

# %%
import numpy as np
import matplotlib.pyplot as plt

c = ["isem sgpa", "second sem sgpa"]
values = [8.4,8]

plt.bar(c, values, color='green')
plt.title=('bar graph')
plt.xlabel("c")
plt.ylabel("values")
plt.show()
