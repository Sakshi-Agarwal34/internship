# %%
d={10,20,40,50,60}
print(d,type(d))
f=(10,20,30,40,50)
print(f,type(f))
s={10:"aa",20:"bb"}
print(s,type(s))
# Out:
# {50, 20, 40, 10, 60} <class 'set'>
# (10, 20, 30, 40, 50) <class 'tuple'>
# {10: 'aa', 20: 'bb'} <class 'dict'>

# %%
def radhe(n1,n2):
    print("multiply",n1*n2)
    print("add",n1+n2)
    print("divide",n1/n2)
    print("subtreact",n1-n2)

a=int(input("num1"))
b=int(input("num2"))
radhe(a,b)
# Out:
# multiply 200
# add 30
# divide 0.5
# subtreact -10

# %%
a=input("enter string")
b=a[-1::-1]

for i in range(0,len(a)):
   if( a[i]==b[i]):
      pass
   else:
      print("not plaindorm")
      break 
print("plaindrom")
# Out:
# plaindrom
