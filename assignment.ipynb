# %%
a="rADHE krishnaa"
b="11111aa"
print(a.lower())



print(a.title())
print(a.upper())

print(a.swapcase())

print(a.casefold())

print(a.center(50))

print(a.count("a"))
print(a.endswith("na"))
print(a.find("kri"))
print(a.isalnum())
print(a.isdigit())
print(a.isnumeric())
a.isspace()
print(a.replace("rA","ram"))
# Out:
# radhe krishnaa
# Radhe Krishnaa
# RADHE KRISHNAA
# Radhe KRISHNAA
# radhe krishnaa
#                   rADHE krishnaa
# 2
# False
# 6
# False
# False
# False
# ramDHE krishnaa

# %%
a=input("enter student name")
b=int(input("enter student class"))
sum=0
for i in range(6):
    marks=int(input("enter marks sub"))
    sum=sum+marks
print("total marks",sum)
p=(sum*100)/500
print("precentage",(sum*100)/500)
if(p>=60):
    print("grade","A")
elif 50<=p or p>60:
    print("grade","B")
elif 40<=p or p>50:
    print("grade","C")
elif 33<=p or p>40:
    print("grade","D") 
else:
    print("fail")
# Out:
# total marks 322
# precentage 64.4
# grade A

# %%
a=input("enter student name")
b=int(input("enter student class"))
sum=0
for i in range(6):
    marks=int(input("enter marks sub"))
    sum=sum+marks
print("total marks",sum)
print("name",a)
print("class",b)
print("precentage",(sum*100)/500)
# Out:
# total marks 440
# name sakshi
# class 12
# precentage 88.0
